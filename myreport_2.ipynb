# %%
from IPython.core.display import Markdown

report_markdown = """
# ✈️ 항공 지연 요인 분석 보고서

**데이터 출처**: `airline_stats.csv`  
**분석 목적**: 항공사별 지연의 원인을 파악하고, 특히 **인재 요인(운항사·관제)**에 초점을 맞춘 개선 방향 제시

---

## ✅ 1. 결측치 확인 및 처리

- `pct_carrier_delay`, `pct_atc_delay`, `pct_weather_delay` 변수에 결측치 존재
- 전체 33,468개 중 약 28건 결측
- `dropna()`로 결측치 제거 후 분석

---

## ✅ 2. 시각적 분석

### 2-1. 히스토그램 (지연 요인별 분포)

- 운항사/관제/기상 지연 모두 **0~20% 구간에 집중**
- 운항사 지연이 상대적으로 **많고 넓게 퍼져 있음**

### 2-2. 박스플롯 (항공사별 운항사 지연률)

- **American, Jet Blue, United**는 중앙값도 높고 이상치도 존재
- **Alaska, Delta**는 상대적으로 지연률이 안정적

---

## ✅ 3. 상관관계 분석

|                   | 운항사 | 관제 | 기상 |
|-------------------|--------|------|------|
| **운항사**         | 1.00   | 0.14 | 0.16 |
| **관제**           | 0.14   | 1.00 | 0.09 |
| **기상**           | 0.16   | 0.09 | 1.00 |

> 상관관계 약함 → 독립적 변수로 분석해도 무방함

---

## ✅ 4. 공분산 분석

- 운항사 ↔ 관제: +3.06  
- 운항사 ↔ 기상: +0.78  
- 관제 ↔ 기상: +0.46  

> 실제 분산 차이가 큼 → 운항사 요인이 전반적으로 **지연 편차에 더 큰 영향**을 줌

---

## ✅ 5. 요약 및 인사이트

- **운항사 요인**은 전체 지연의 주요 원인
- **항공사별 정책·정비 운영 차이**가 영향을 줌
- 관제 지연은 예측 어려운 변동 요소로 보이지만 일부 항공사에서 높은 비율이 보임

---

## ✅ 6. 다음 분석 방향 제안

- 항공사별 월별·노선별 지연 분석
- 지연 시간(분 단위) 데이터가 있다면 **회귀분석**
- 머신러닝 분류 모델 적용 (지연 여부 예측 등)
"""

display(Markdown(report_markdown))
# Out:
# # ✈️ 항공 지연 요인 분석 보고서
#
# **데이터 출처**: `airline_stats.csv`
# **분석 목적**: 항공사별 지연의 원인을 파악하고, 특히 **인재 요인(운항사·관제)**에 초점을 맞춘 개선 방향 제시
#
# ---
#
# ## ✅ 1. 결측치 확인 및 처리
#
# - `pct_carrier_delay`, `pct_atc_delay`, `pct_weather_delay` 변수에 결측치 존재
# - 전체 33,468개 중 약 28건 결측
# - `dropna()`로 결측치 제거 후 분석
#
# ---
#
# ## ✅ 2. 시각적 분석
#
# ### 2-1. 히스토그램 (지연 요인별 분포)
#
# - 운항사/관제/기상 지연 모두 **0~20% 구간에 집중**
# - 운항사 지연이 상대적으로 **많고 넓게 퍼져 있음**
#
# ### 2-2. 박스플롯 (항공사별 운항사 지연률)
#
# - **American, Jet Blue, United**는 중앙값도 높고 이상치도 존재
# - **Alaska, Delta**는 상대적으로 지연률이 안정적
#
# ---
#
# ## ✅ 3. 상관관계 분석
#
# |                   | 운항사 | 관제 | 기상 |
# |-------------------|--------|------|------|
# | **운항사**         | 1.00   | 0.14 | 0.16 |
# | **관제**           | 0.14   | 1.00 | 0.09 |
# | **기상**           | 0.16   | 0.09 | 1.00 |
#
# > 상관관계 약함 → 독립적 변수로 분석해도 무방함
#
# ---
#
# ## ✅ 4. 공분산 분석
#
# - 운항사 ↔ 관제: +3.06
# - 운항사 ↔ 기상: +0.78
# - 관제 ↔ 기상: +0.46
#
# > 실제 분산 차이가 큼 → 운항사 요인이 전반적으로 **지연 편차에 더 큰 영향**을 줌
#
# ---
#
# ...
