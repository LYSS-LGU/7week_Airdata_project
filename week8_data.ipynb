# %% [markdown]
# # 도교공주야별교통사고통계
#
# ### [25.06.30] 8주차 오후수업.

# %% [markdown]
# # 📘 교통사고 분석 보고서
# 주제: 가해자 법규 위반별 주야 교통사고 비교 분석 및 야간 취약 유형 도출
# 출처: 한국도로교통공단, 2023년 자료
#
# ## 1️⃣ 분석 목적
# 가해자의 법규 위반 유형에 따른 교통사고 발생 현황을 주간/야간으로 구분해 분석함
#
# 야간에 사고가 더 빈번하거나 치명적인 취약 위반 유형을 도출하여 정책 제안 또는 예방 교육 자료로 활용
#
# ## 2️⃣ 데이터 개요
# 데이터 출처: 한국도로교통공단
#
# 분석 대상: 2023년 기준 교통사고 통계
#
# 주요 변수:
#
# ***가해자법규위반***, ***주야***, ***사고건수***, ***사망자수***, ***중상자수***, ***경상자수***, ***부상신고자수***
#
# ## 3️⃣ 주야별 사고건수 비교 (요약)
# | 위반 유형       | 주간 사고  | 야간 사고  | 야간 비율 (%) |
# | ----------- | ------ | ------ | --------- |
# | 안전운전 의무 불이행 | 69,737 | 41,131 | 37.1%     |
# | 신호위반        | 13,489 | 9,955  | 42.5%     |
# | 안전거리 미확보    | 15,407 | 6,824  | 30.7%     |
# | 기타          | 10,871 | 5,210  | 32.4%     |
# | 교차로 통행방법 위반 | 7,699  | 3,361  | 30.4%     |
# | 보행자 보호의무 위반 | 4,483  | 2,744  | 38.0%     |
# | 중앙선 침범      | 4,801  | 2,584  | **35.0%** |
# ```
#  ⚠️ 야간 사고 비율이 높은 순서:
# 1. 신호위반(42.5%),
# 2. 보행자 보호의무 위반(38.0%),
# 3. 안전운전 의무 불이행(37.1%)
# → 조도 부족, 졸음운전, 낮은 인지 능력 등 야간 운전 특성 반영 가능성
# ```
#
# ## 4️⃣ 시사점 및 제안
#
# ### ✅ 정책 제안
# - 신호위반 및 보행자 보호의무 야간 단속 강화
#
# - 특히 보행자 밀집 지역, 주거 밀집 지역 주변
#
# - 야간 운전자 대상 교육 강화
#
# - 시야 확보, 조도 인식 훈련 포함
#
# - AI 기반 스마트 가로등, 교차로 알림 시스템 도입 검토
#
# ### ✅ 교육 및 캠페인
# - “야간 사고 조심하세요” 테마의 집중 캠페인
#
# - 실제 사례 중심의 시뮬레이션 교육 실시
#
# ## 5️⃣ 결론
#
# - 전체 교통사고 건수는 주간에 더 많이 발생하지만,
# - 특정 위반 유형에서는 야간 사고 비중이 상대적으로 높게 나타남.
# - 이는 조도 부족, 운전자 집중력 저하, 보행자의 안전 불감증 등 환경적 요인이 큰 영향을 미친다는 점을 시사함.
# - 따라서 정책·교육·인프라 측면에서 **야간 대응 중심의 교통안전 대책**이 필요함.

# %%
import pandas as pd

# 파일 경로 설정
file_path = r"C:\githome\7week_Airdata_project\autocarz\data\도교공주야별교통사고통계\한국도로교통공단_가해운전자 법규위반별 주야별 교통사고 통계_20231231.csv"

# CSV 파일 불러오기
# df = pd.read_csv(file_path, encoding='utf-8')  # 한글 깨짐 시 'cp949'로 변경

# 인코딩을 cp949로 지정하여 다시 읽기
df = pd.read_csv(file_path, encoding='cp949')

print("\n=== df 출력 ===\n",df)


# 열(Column) 이름 확인
print("\n=== 열 이름 ===\n", df.columns)

# 첫 번째 행만 출력
print("\n=== 첫 번째 행 (head) ===\n", df.head(1))

# 또는
print("\n=== 첫 번째 행 (iloc) ===\n", df.iloc[0])
# Out:
# === df 출력 ===
#          가해자법규위반 주야   사고건수  사망자수   중상자수   경상자수  부상신고자수
# 0   교차로 통행방법 위반  주   7699    25   1777   8901     769
# 1   교차로 통행방법 위반  야   3361     2    772   3923     351
# 2            기타  주  10871   111   3271  11461    1157
# 3            기타  야   5210   146   1548   5228     629
# 4   보행자 보호의무 위반  주   4483    73   1909   2588     132
# 5   보행자 보호의무 위반  야   2744    25   1073   1738     133
# 6          신호위반  주  13489   120   4597  14975     876
# 7          신호위반  야   9955    79   3679  10957     707
# 8      안전거리 미확보  주  15407    28   2617  20216    1860
# 9      안전거리 미확보  야   6824    19   1132   8942     730
# 10  안전운전 의무 불이행  주  69737   938  17347  72608    7115
# 11  안전운전 의무 불이행  야  41131   816  10137  41468    4289
# 12       중앙선 침범  주   4801   107   2078   5703     319
# 13       중앙선 침범  야   2584    62   1052   2861     174
#
# === 열 이름 ===
#  Index(['가해자법규위반', '주야', '사고건수', '사망자수', '중상자수', '경상자수', '부상신고자수'], dtype='object')
#
# === 첫 번째 행 (head) ===
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 수동 입력 (사용자 제공 데이터를 기반으로 DataFrame 생성)
data = {
    '가해자법규위반': ['교차로 통행방법 위반', '교차로 통행방법 위반', '기타', '기타', '보행자 보호의무 위반', '보행자 보호의무 위반',
                 '신호위반', '신호위반', '안전거리 미확보', '안전거리 미확보', '안전운전 의무 불이행', '안전운전 의무 불이행',
                 '중앙선 침범', '중앙선 침범'],
    '주야': ['주', '야'] * 7,
    '사고건수': [7699, 3361, 10871, 5210, 4483, 2744, 13489, 9955, 15407, 6824, 69737, 41131, 4801, 2584],
    '사망자수': [25, 2, 111, 146, 73, 25, 120, 79, 28, 19, 938, 816, 107, 62],
    '중상자수': [1777, 772, 3271, 1548, 1909, 1073, 4597, 3679, 2617, 1132, 17347, 10137, 2078, 1052],
    '경상자수': [8901, 3923, 11461, 5228, 2588, 1738, 14975, 10957, 20216, 8942, 72608, 41468, 5703, 2861],
    '부상신고자수': [769, 351, 1157, 629, 132, 133, 876, 707, 1860, 730, 7115, 4289, 319, 174]
}

df = pd.DataFrame(data)

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 가해자 법규위반별 사고건수 차트 (주/야 구분)
pivot = df.pivot_table(index='가해자법규위반', columns='주야', values='사고건수', aggfunc='sum')

# 시각화
pivot.plot(kind='bar', figsize=(10, 6), title='가해자 법규 위반별 주야 사고건수 비교')
plt.ylabel('사고건수')
plt.xlabel('가해자 법규 위반 유형')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# 기초 통계량 확인
print(df.describe())
# Out:
#                사고건수        사망자수          중상자수          경상자수       부상신고자수
# count     14.000000   14.000000     14.000000     14.000000    14.000000
# mean   14164.000000  182.214286   3784.928571  15112.071429  1374.357143
# std    18779.261684  298.479526   4582.449940  19475.735386  1969.975931
# min     2584.000000    2.000000    772.000000   1738.000000   132.000000
# 25%     4562.500000   25.750000   1236.000000   4249.250000   327.000000
# 50%     7261.500000   76.000000   1993.500000   8921.500000   718.500000
# 75%    12834.500000  117.750000   3577.000000  14096.500000  1086.750000
# max    69737.000000  938.000000  17347.000000  72608.000000  7115.000000

# %%
# ✅ 1. 기초 통계량 요약 시각화 (막대 그래프)

import matplotlib.pyplot as plt

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# describe 결과 저장
desc = df.describe()

# 평균(mean) 시각화
desc.loc['mean'].plot(kind='bar', title='각 항목별 평균값', figsize=(10,6))
plt.ylabel('평균 수치')
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# ✅ 2. 박스 플롯(Boxplot) – 이상치/분포 보기

# 수치형 열만 박스플롯으로 시각화
df[['사고건수', '사망자수', '중상자수', '경상자수', '부상신고자수']].plot(kind='box', title='항목별 분포 (Boxplot)', figsize=(10,6))
plt.ylabel('수치')
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# 위반 유형별 전체 사고 건수 합계

import matplotlib.pyplot as plt

# 한글 폰트 설정 (Windows 기준)
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 시각화
total_accidents.plot(kind='bar', figsize=(10, 6), title='위반유형별 사고건수 총합')
plt.ylabel('사고 건수')
plt.xlabel('가해자 법규 위반 유형')
plt.xticks(rotation=45)  # x축 라벨 회전
plt.tight_layout()
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       7 plt.rcParams['axes.unicode_minus'] = False
#       9 # 시각화
# ---> 10 total_accidents.plot(kind='bar', figsize=(10, 6), title='위반유형별 사고건수 총합')
#      11 plt.ylabel('사고 건수')
#      12 plt.xlabel('가해자 법규 위반 유형')
#
# NameError: name 'total_accidents' is not defined

# %%
# 주 vs 야 사고건수 비교 시각화

import pandas as pd
import matplotlib.pyplot as plt

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 데이터 불러오기
df = pd.read_csv(file_path, encoding='cp949')

# 주야별 사고 건수
day_night = df.groupby('주야')['사고건수'].sum()

# 그래프 출력
day_night.plot(kind='bar', title='주야별 사고건수 비교')
plt.ylabel('사고 건수')
plt.grid(True, axis='y', linestyle='--', alpha=0.5)

plt.xlabel('주야')
plt.show()

# %%
# 가해자 법규 위반별 주야 사고 비교

pivot = df.pivot_table(index='가해자법규위반', columns='주야', values='사고건수', aggfunc='sum')
print("\n=== 위반유형별 주야 사고건수 ===\n", pivot)

# %%
# ✅ 주야별 사고건수 비교 시각화 (가로 막대 그래프)

import matplotlib.pyplot as plt

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 시각화 (가로 막대그래프)
pivot.plot(kind='barh', figsize=(10, 7), title='가해자 법규 위반별 주야 사고건수 비교')
plt.xlabel('사고 건수')
plt.ylabel('가해자 법규 위반')
plt.grid(True, axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
